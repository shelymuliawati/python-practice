# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\SHELY MULIAWATI\Desktop\夢\Porto\list members.xlsx")

# %%
df
# Out:
#     Start_Date  Gen                               Name        DoB Final_Date  \
# 0   2011-11-02    1              Intania Pratama Ilham 1991-07-19 2012-02-12
# 1   2011-11-02    1              Siti Gayatri Abhirama 1993-03-11 2012-02-12
# 2   2011-11-02    1                       Allisa Astri 1990-06-23 2012-05-10
# 3   2011-11-02    1                    Fahira Al Idrus 1998-07-27 2012-05-10
# 4   2011-11-02    1                    Neneng Rosdiana 1999-01-24 2012-11-25
# ..         ...  ...                                ...        ...        ...
# 180 2019-12-01    9          Chalista Ellysia Sugianto 2006-03-01        NaT
# 181 2019-12-01    9                      Putri Elzahra 2006-05-19        NaT
# 182 2019-12-01    9       Kathrina Irene Indarto Putri 2006-07-26        NaT
# 183 2019-12-01    9  Christabel Angela Jocelyn Santoso 2007-08-17        NaT
# 184 2019-12-01    9           Caithlyn Gwyneth Santoso 2009-03-26        NaT
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Start_Date      185 non-null    datetime64[ns]
#  1   Gen             185 non-null    int64
#  2   Name            185 non-null    object
#  3   DoB             185 non-null    datetime64[ns]
#  4   Final_Date      115 non-null    datetime64[ns]
#  5   Status          185 non-null    object
#  6   Team            185 non-null    object
#  7   Chinese_Zodiac  185 non-null    object
#  8   Zodiac          185 non-null    object
#  9   Element         185 non-null    object
#  10  Qualities       185 non-null    object
#  11  LengthofStay    115 non-null    float64
#  12  Special_Status  14 non-null     object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(8)
# memory usage: 18.9+ KB
#               Gen  LengthofStay
# count  185.000000    115.000000
# ...

# %%
df.isnull().sum()
# Out:
# Start_Date          0
# Gen                 0
# Name                0
# DoB                 0
# Final_Date         70
# Status              0
# Team                0
# Chinese_Zodiac      0
# Zodiac              0
# Element             0
# Qualities           0
# LengthofStay       70
# Special_Status    171
# dtype: int64

# %%
df.head(5)
# Out:
#   Start_Date  Gen                   Name        DoB Final_Date  \
# 0 2011-11-02    1  Intania Pratama Ilham 1991-07-19 2012-02-12
# 1 2011-11-02    1  Siti Gayatri Abhirama 1993-03-11 2012-02-12
# 2 2011-11-02    1           Allisa Astri 1990-06-23 2012-05-10
# 3 2011-11-02    1        Fahira Al Idrus 1998-07-27 2012-05-10
# 4 2011-11-02    1        Neneng Rosdiana 1999-01-24 2012-11-25
#
#                 Status       Team Chinese_Zodiac     Zodiac Element Qualities  \
# 0             Resigned  Ex-member           Goat     Cancer   Water  Cardinal
# 1             Resigned  Ex-member        Rooster     Pisces   Water   Mutable
# 2  Contract Terminated  Ex-member          Horse     Cancer   Water  Cardinal
# 3  Contract Terminated  Ex-member          Tiger        Leo    Fire     Fixed
# 4            Graduated  Ex-member         Rabbit  Capricorn   Earth  Cardinal
#
#    LengthofStay Special_Status
# 0         102.0            NaN
# 1         102.0            NaN
# ...

# %%
df[['Gen','Name']]
# Out:
#      Gen                               Name
# 0      1              Intania Pratama Ilham
# 1      1              Siti Gayatri Abhirama
# 2      1                       Allisa Astri
# 3      1                    Fahira Al Idrus
# 4      1                    Neneng Rosdiana
# ..   ...                                ...
# 180    9          Chalista Ellysia Sugianto
# 181    9                      Putri Elzahra
# 182    9       Kathrina Irene Indarto Putri
# 183    9  Christabel Angela Jocelyn Santoso
# 184    9           Caithlyn Gwyneth Santoso
#
# [185 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Start_Date      185 non-null    datetime64[ns]
#  1   Gen             185 non-null    int64
#  2   Name            185 non-null    object
#  3   DoB             185 non-null    datetime64[ns]
#  4   Final_Date      115 non-null    datetime64[ns]
#  5   Status          185 non-null    object
#  6   Team            185 non-null    object
#  7   Chinese_Zodiac  185 non-null    object
#  8   Zodiac          185 non-null    object
#  9   Element         185 non-null    object
#  10  Qualities       185 non-null    object
#  11  LengthofStay    115 non-null    float64
#  12  Special_Status  14 non-null     object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(8)
# memory usage: 18.9+ KB

# %%
df.Special_Status.unique()
# Out:
# array([nan, 'JKT48 Captain, T Captain', 'J Captain, KIII Captain',
#        'JKT48 Captain, J Captain', 'T Vice Captain ', 'T Captain',
#        'J Captain', 'JKT48 Captain', 'Vice Captain, J Captain',
#        'KIII Captain'], dtype=object)

# %%
df.columns = ['StartDate','Gen','Name','DOB','FD','Status','Team','CZ','Zodiac','Element','Qualities','LoS','SpecialStatus']

# %%
df.Element.unique()
# Out:
# array(['Water', 'Fire', 'Earth', 'Air'], dtype=object)

# %%
df.Zodiac.unique()
# Out:
# array(['Cancer', 'Pisces', 'Leo', 'Capricorn', 'Sagittarius', 'Virgo',
#        'Taurus', 'Scorpio', 'Gemini', 'Aquarius', 'Aries', 'Libra'],
#       dtype=object)

# %%
df.CZ.unique()
# Out:
# array(['Goat', 'Rooster', 'Horse', 'Tiger', 'Rabbit', 'Rat', 'Dog', 'Ox',
#        'Pig', 'Monkey', 'Dragon', 'Snake'], dtype=object)

# %%
df.Team.unique()
# Out:
# array(['Ex-member', ' J ', ' KIII ', ' J, KIII,T', 'T',
#        'Class A Academy '], dtype=object)

# %%
df.Status.unique()
# Out:
# array(['Resigned', 'Contract Terminated', 'Graduated', 'Dismissed',
#        'Active Member', 'Transferred', 'Left'], dtype=object)

# %%
df.Qualities.unique()
# Out:
# array(['Cardinal', 'Mutable', 'Fixed'], dtype=object)

# %%
df = pd.read_excel(r"C:\Users\SHELY MULIAWATI\Desktop\porto\list members.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Start_Date      185 non-null    datetime64[ns]
#  1   Gen             185 non-null    int64
#  2   Name            185 non-null    object
#  3   DoB             185 non-null    datetime64[ns]
#  4   Final_Date      185 non-null    object
#  5   Status          185 non-null    object
#  6   Team            185 non-null    object
#  7   Chinese_Zodiac  185 non-null    object
#  8   Zodiac          185 non-null    object
#  9   Element         185 non-null    object
#  10  LengthofStay    185 non-null    object
#  11  Special_Status  14 non-null     object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 17.5+ KB

# %%
df.head(5)
# Out:
#    Gen                   Name        DoB           Final_Date  \
# 0    1  Intania Pratama Ilham 1991-07-19  2012-02-12 00:00:00
# 1    1  Siti Gayatri Abhirama 1993-03-11  2012-02-12 00:00:00
# 2    1           Allisa Astri 1990-06-23  2012-05-10 00:00:00
# 3    1        Fahira Al Idrus 1998-07-27  2012-05-10 00:00:00
# 4    1        Neneng Rosdiana 1999-01-24  2012-11-25 00:00:00
#
#                 Status       Team Chinese_Zodiac     Zodiac Element  \
# 0             Resigned  Ex-member           Goat     Cancer   Water
# 1             Resigned  Ex-member        Rooster     Pisces   Water
# 2  Contract Terminated  Ex-member          Horse     Cancer   Water
# 3  Contract Terminated  Ex-member          Tiger        Leo    Fire
# 4            Graduated  Ex-member         Rabbit  Capricorn   Earth
#
#   LengthofStay Special_Status
# 0          102            NaN
# 1          102            NaN
# 2          190            NaN
# 3          190            NaN
# ...

# %%
df.drop(["StartDate","FD"],axis=1,inplace=True)

# %%
df.Status.unique()
# Out:
# array(['Resigned', 'Contract Terminated', 'Graduated', 'Dismissed',
#        'Active Member', 'Transferred', 'Left'], dtype=object)

# %%
df = pd.read_excel(r"C:\Users\SHELY MULIAWATI\Desktop\porto\list members.xlsx")

# %%
df.Chinese_Zodiac.unique()
# Out:
# array(['Goat', 'Rooster', 'Horse', 'Tiger', 'Rabbit', 'Rat', 'Dog', 'Ox',
#        'Pig', 'Monkey', 'Dragon', 'Snake'], dtype=object)

# %%
df.Zodiac.unique()
# Out:
# array(['Cancer', 'Pisces', 'Leo', 'Capricorn', 'Sagittarius', 'Virgo',
#        'Taurus', 'Scorpio', 'Gemini', 'Aquarius', 'Aries', 'Libra'],
#       dtype=object)

# %%
df.Element.unique()
# Out:
# array(['Water', 'Fire', 'Earth', 'Air'], dtype=object)

# %%
df.Special_Status.unique()
# Out:
# array([nan, 'JKT48 Captain, T Captain', 'J Captain, KIII Captain',
#        'JKT48 Captain, J Captain', 'T Vice Captain ', 'T Captain',
#        'J Captain', 'JKT48 Captain', 'Vice Captain, J Captain',
#        'KIII Captain'], dtype=object)

# %%
for col in["CZ","Zodiac","Element","Qualities","Status","Team","SpecialStatus"]:
    plt.figure(figsize=(13,9))
    sns.countplot(df[col])
    plt.grid(True)
    plt.show()

# %%
df.isnull().sum()
# Out:
# StartDate          0
# Gen                0
# Name               0
# DOB                0
# FD                70
# Status             0
# Team               0
# CZ                 0
# Zodiac             0
# Element            0
# Qualities          0
# LoS               70
# SpecialStatus    171
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Start_Date      185 non-null    datetime64[ns]
#  1   Gen             185 non-null    int64
#  2   Name            185 non-null    object
#  3   DoB             185 non-null    datetime64[ns]
#  4   Final_Date      115 non-null    datetime64[ns]
#  5   Status          185 non-null    object
#  6   Team            185 non-null    object
#  7   Chinese_Zodiac  185 non-null    object
#  8   Zodiac          185 non-null    object
#  9   Element         185 non-null    object
#  10  LengthofStay    115 non-null    float64
#  11  Special_Status  14 non-null     object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(7)
# memory usage: 17.5+ KB

# %%
df['LengthofStay']
# Out:
# 0      102.0
# 1      102.0
# 2      190.0
# 3      190.0
# 4      389.0
#        ...
# 180      NaN
# 181      NaN
# 182      NaN
# 183      NaN
# 184      NaN
# Name: LengthofStay, Length: 185, dtype: float64

# %%
df.isnull().sum()
# Out:
# Start_Date          0
# Gen                 0
# Name                0
# DoB                 0
# Final_Date         70
# Status              0
# Team                0
# Chinese_Zodiac      0
# Zodiac              0
# Element             0
# LengthofStay       70
# Special_Status    171
# dtype: int64

# %%
df['LoS'].skew() #Karena skew > +0.1 positive skewness. Then fill the misval with MEDIAN
# Out:
# 0.6812293991546546

# %%
df.LoS.fillna(df.LoS.median(),inplace=True)

# %%
df['LoS'].skew()
# Out:
# 1.2261366889928207

# %%
df['LoS']
# Out:
# 0      102.0
# 1      102.0
# 2      190.0
# 3      190.0
# 4      389.0
#        ...
# 180    763.0
# 181    763.0
# 182    763.0
# 183    763.0
# 184    763.0
# Name: LoS, Length: 185, dtype: float64

# %%
df.isnull().sum()
# Out:
# StartDate          0
# Gen                0
# Name               0
# DOB                0
# FD                70
# Status             0
# Team               0
# CZ                 0
# Zodiac             0
# Element            0
# Qualities          0
# LoS                0
# SpecialStatus    171
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gen            185 non-null    int64
#  1   Name           185 non-null    object
#  2   DOB            185 non-null    datetime64[ns]
#  3   Status         185 non-null    object
#  4   Team           185 non-null    object
#  5   CZ             185 non-null    object
#  6   Zodiac         185 non-null    object
#  7   Element        185 non-null    object
#  8   Qualities      185 non-null    object
#  9   LoS            185 non-null    float64
#  10  SpecialStatus  14 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(8)
# memory usage: 16.0+ KB

# %%
df.drop(["Start_Date"],axis=1,inplace=True)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gen            185 non-null    int64
#  1   Name           185 non-null    object
#  2   DOB            185 non-null    datetime64[ns]
#  3   Status         185 non-null    object
#  4   Team           185 non-null    object
#  5   CZ             185 non-null    object
#  6   Zodiac         185 non-null    object
#  7   Element        185 non-null    object
#  8   Qualities      185 non-null    object
#  9   LoS            185 non-null    float64
#  10  SpecialStatus  14 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(8)
# memory usage: 16.0+ KB
#               Gen          LoS
# count  185.000000   185.000000
# mean     4.345946   923.740541
# std      2.608368   699.015898
# min      1.000000     7.000000
# 25%      2.000000   522.000000
# ...

# %%
for col in["LoS"]:
    plt.figure(figsize=(10,8))
    plt.scatter(df.index,df[col])
    plt.ylabel("Days Staying")
    plt.xlabel("Total Members")
    plt.title(col)

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LoS'])
plt.title("Length of Stay Per Person (Days)")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LoS'][df.Element=='Water'])
sns.distplot(df['LoS'][df.Element=='Fire'])
sns.distplot(df['LoS'][df.Element=='Earth'])
sns.distplot(df['LoS'][df.Element=='Air'])
plt.title("LoS Distribution between Elements")
plt.legend(['Water','Fire','Earth','Air'])
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LoS'][df.Element=='Fire'])
plt.title("LoS Distribution")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LengthofStay'][df.Element=='Earth'])
plt.title("LoS Distribution")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LengthofStay'][df.Element=='Air'])
plt.title("LoS Distribution")
plt.show()

# %%
for col in ["LoS"]:
    plt.figure(figsize=(10,6))
    plt.scatter(df.Status, df[col])
    plt.xticks([0,1])
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize=(15,14))
sns.pairplot(df, hue="Element")

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LengthofStay'][df.Zodiac=='Aries'])
plt.title("LoS Distribution")
plt.show()

# %%
for col in ["Zodiac","Element","CZ","Qualities"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count", palette="ch:.25", data=df,
            height=5, aspect=2);

# %%
sns.catplot(x='Zodiac', y='LoS', 
            data=df,
            jitter=False,
            height=3, aspect=3)

# %%
sns.catplot(x='Element', y='LoS', 
            data=df,
            jitter=False,
            height=5, aspect=2)

# %%
for col in ["Status","Team"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count", palette="ch:.25", data=df,
            height=5, aspect=2);

# %%
sns.barplot(x='Element',y='LengthofStay',data=df)

# %%
for col in ["Zodiac"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count",
            palette="ch:.25", data=df,
            order = df['Zodiac'].value_counts().index,
            height=5, aspect=2);

# %%
for col in ["Element"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count",
            palette="ch:.25", data=df,
            order = df['Element'].value_counts().index,
            height=5, aspect=2);

# %%
for col in ["Chinese_Zodiac"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count",
            palette="ch:.25", data=df,
            order = df['Chinese_Zodiac'].value_counts().index,
            height=5, aspect=2);

# %%
for col in ["Status"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count",
            palette="ch:.25", data=df,
            order = df['Status'].value_counts().index,
            height=5, aspect=2);

# %%
for col in ["Team"]:
    plt.figure(figsize=(12,5))
    sns.catplot(x=col, kind="count",
            palette="ch:.25", data=df,
            order = df['Team'].value_counts().index,
            height=5, aspect=2);

# %%
for col in ["Team"]:
    plt.figure(figsize=(13,4))
sns.stripplot(x="Status",y="LengthofStay",data=df, jitter=True, size=10,hue='Element',palette='Set2')

# %%
for col in ["Team"]:
    plt.figure(figsize=(13,4))
sns.stripplot(x="Status",y="LengthofStay",data=df, jitter=True, size=10,hue='Gen',palette='Set2')

# %%
for col in ["Team"]:
    plt.figure(figsize=(13,4))
sns.stripplot(x="Gen",y="LengthofStay",data=df, jitter=True, size=10,hue='Status',palette='Set2')

# %%
for col in ["Team"]:
    plt.figure(figsize=(13,4))
sns.stripplot(x="Chinese_Zodiac",y="LengthofStay",data=df, jitter=True, size=10,hue='Element',palette='Set2')

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Zodiac[df.Status=='Active Member'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Zodiac[df.Status=='Left'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Zodiac[df.Status=='Resigned'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Zodiac[df.Status=='Contract Terminated'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Zodiac[df.Status=='Dismissed'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Status=='Active Member'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Status=='Left'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Status=='Dismissed'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Status=='Contract Terminated'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Status=='Resigned'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Team=='T'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Team==' KIII '],
             palette='viridis')
plt.show()

# %%
df.Team.unique()
# Out:
# array(['Ex-member', ' J ', ' KIII ', ' J, KIII,T', 'T',
#        'Class A Academy '], dtype=object)

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Team==' J '],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Element[df.Team=='Class A Academy '],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Qualities[df.Status=='Active Member'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(df.Qualities[df.Status=='Dismissed'],
             palette='viridis')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LengthofStay'][df.Qualities=='Mutable'])
sns.distplot(df['LengthofStay'][df.Qualities=='Cardinal'])
sns.distplot(df['LengthofStay'][df.Qualities=='Fixed'])
plt.title("LoS Distribution by Qualities")
plt.legend(['Mutable','Cardinal','Fixed'])
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LengthofStay'][df.Element=='Water'])
sns.distplot(df['LengthofStay'][df.Element=='Earth'])
sns.distplot(df['LengthofStay'][df.Element=='Air'])
sns.distplot(df['LengthofStay'][df.Element=='Fire'])
plt.title("LoS Distribution by Elements")
plt.legend(['Water','Earth','Air','Fire'])
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['LengthofStay'][df.Qualities=='Mutable'])
sns.distplot(df['LengthofStay'][df.Qualities=='Fixed'])
plt.title("LoS Distribution by Qualities")
plt.legend(['Mutable','Cardinal','Fixed'])
plt.show()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(12,5))
sns.catplot(x="Qualities", y="LengthofStay", data=df,jitter=False)
sns.catplot(x="Element", y="LengthofStay", data=df,jitter=False)

# %%
sns.catplot(x="Chinese_Zodiac", y="LengthofStay", data=df, jitter=False, size=7)
sns.catplot(x="Zodiac", y="LengthofStay", data=df,jitter=False, size=9)

# %%
df['LengthofStay'].mean()
# Out:
# 1021.5826086956522

# %%
df['LengthofStay'].min()
# Out:
# 7.0

# %%
df['LengthofStay'].max()
# Out:
# 2958.0

# %%
df['LengthofStay'].var()
# Out:
# 763132.8418001528

# %%
df['LengthofStay'].std()
# Out:
# 873.5747488338665

# %%
df['LengthofStay'].median()
# Out:
# 763.0

# %%
sns.pairplot(df)

# %%
sns.jointplot(x="LengthofStay", y="Gen", data=df);

# %%
sns.scatterplot(data=df, x="LengthofStay", y="Rank")

# %%
for col in ["Team"]:
    plt.figure(figsize=(13,6))
sns.stripplot(x="Zodiac",y="LoS",data=df, jitter=True, size=10,hue='Status',palette='Set2')

# %%
for col in ["Team"]:
    plt.figure(figsize=(13,6))
sns.stripplot(x="Qualities", y="LoS",data=df, jitter=True, size=15,hue='Status',palette='Set2')

# %%
plt.figure(figsize=(13,6))
sns.countplot(df.Status[df.Qualities=='Mutable'])
plt.show()

# %%
plt.figure(figsize=(13,6))
sns.countplot(df.Status[df.Qualities=='Fixed'])
plt.show()

# %%
plt.figure(figsize=(13,6))
sns.countplot(df.Status[df.Qualities=='Cardinal'])
plt.show()
