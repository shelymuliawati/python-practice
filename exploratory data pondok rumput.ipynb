# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\SHELY MULIAWATI\Desktop\REVISI SETELAH SIDANG\DATAPYTHON.xlsx")

# %%
df.head()
# Out:
#   Diabetic_Risk  Gender  Age Smoking_Habit Medicine_Consumption Left_Handed  \
# 0       No Risk    Male   69           Yes                   No          No
# 1       No Risk  Female   70            No                  Yes          No
# 2       No Risk  Female   75            No                   No          No
# 3       No Risk  Female   59            No                   No          No
# 4       No Risk  Female   60            No                  Yes          No
#
#      BMI   Occupation
# 0  27.01  Not Working
# 1  24.78    Housewife
# 2  20.63    Housewife
# 3  26.30    Housewife
# 4  27.78    Housewife

# %%
plt.scatter(df['Age'],df['BMI'])
plt.title('Age','BMI')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d1ac0348963d> in <module>
#       1 plt.scatter(df['Age'],df['BMI'])
# ----> 2 plt.title('Age','BMI')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in title(label, fontdict, loc, pad, **kwargs)
#    3061 def title(label, fontdict=None, loc='center', pad=None, **kwargs):
#    3062     return gca().set_title(
# -> 3063         label, fontdict=fontdict, loc=loc, pad=pad, **kwargs)
#    3064
#    3065
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_title(self, label, fontdict, loc, pad, **kwargs)
#     210         title.update(default)
#     211         if fontdict is not None:
# --> 212             title.update(fontdict)
#     213         title.update(kwargs)
#     214         return title
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in update(self, kwargs)
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="Diabetic_Risk")

# %%
cor = df.corr()
plt.figure
ax = sns.heatmap(cor,annot=True,cmap="seismic")
bot,top=ax.get_ylim()
ax.set_ylim(bot+0.5,top-0.5)
plt.show()

# %%
for col in ["Gender","Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.catplot(x=col, y="Age", hue="Diabetic_Risk", kind="bar", data=df)

# %%
for col in ["Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.catplot(x=col, y="BMI", hue="Diabetic_Risk", kind="bar", data=df)

# %%
for col in ["Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.catplot(x=col, y="BMI", kind="bar", data=df)

# %%
for col in ["Gender","Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.countplot(df[col][df.Diabetic_Risk=='High Risk'])
    plt.title("High Risk Status Category")

# %%
for col in ["Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.countplot(df[col])

# %%
for col in ["Gender","Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.pointplot(x=col,y="Age",hue="Diabetic_Risk",data=df)
    plt.show()

# %%
for col in ["Gender","Smoking_Habit","Medicine_Consumption","Left_Handed","Occupation"]:
    plt.figure(figsize=(10,5))
    sns.pointplot(x=col,y="BMI",hue="Diabetic_Risk",data=df)
    plt.show()

# %%
plt.figure(figsize=(2,3))
sns.countplot(df.Gender[df.Diabetic_Risk=='High Risk'])

# %%
plt.figure(figsize=(2,3))
sns.countplot(df.Smoking_Habit[df.Diabetic_Risk=='High Risk'])

# %%
plt.figure(figsize=(2,3))
sns.countplot(df.Medicine_Consumption[df.Diabetic_Risk=='High Risk'])

# %%
plt.figure(figsize=(2,3))
sns.countplot(df.Left_Handed[df.Diabetic_Risk=='High Risk'])

# %%
plt.figure(figsize=(4,3))
sns.countplot(df.Occupation[df.Diabetic_Risk=='High Risk'])
